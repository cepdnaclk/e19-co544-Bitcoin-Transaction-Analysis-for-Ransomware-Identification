# %% [markdown]
# <a href="https://colab.research.google.com/github/cepdnaclk/e19-co544-Bitcoin-Transaction-Analysis-for-Ransomware-Identification/blob/main/ML_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing, neighbors
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('/content/drive/MyDrive/dataset_project/BitcoinHeistData.csv')

# %%
for column in df.columns:
  print(column)


print(df.dtypes)
# Out:
# address
# year
# day
# length
# weight
# count
# looped
# neighbors
# income
# label
# address       object
# year           int64
# day            int64
# length         int64
# weight       float64
# count          int64
# looped         int64
# neighbors      int64
# income       float64
# label         object
# dtype: object

# %%
plt.figure()  # create a new figure
df['length'].hist(bins=140)  # plot histogram with 50 bins
plt.title('length')  # set title as column name
plt.show()  # display the plot

# %%
plt.figure()  # create a new figure
df['year'].hist(bins=10)  # plot histogram with 50 bins
plt.title('year')  # set title as column name
plt.show()  # display the plot

# %%
plt.figure()  # create a new figure
df['weight'].hist(bins=100)  # plot histogram with 50 bins
plt.title('weight')  # set title as column name
plt.show()  # display the plot

# %%
plt.figure()  # create a new figure
df['neighbors'].hist(bins=100)  # plot histogram with 50 bins
plt.title('neighbors')  # set title as column name
plt.show()  # display the plot

# %%
plt.figure()  # create a new figure
df['count'].hist(bins=100)  # plot histogram with 50 bins
plt.title('count')  # set title as column name
plt.show()  # display the plot

# %%
plt.figure()  # create a new figure
df['looped'].hist(bins=100)  # plot histogram with 50 bins
plt.title('looped ')  # set title as column name
plt.show()  # display the plot

# %%
plt.figure()  # create a new figure
df['income'].hist(bins=100)  # plot histogram with 50 bins
plt.title('income')  # set title as column name
plt.show()  # display the plot
